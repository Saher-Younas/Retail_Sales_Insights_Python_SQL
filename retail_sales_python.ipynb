# %% [markdown]
# # Read data from the file and handle null values

# %%
import pandas as pd
df= pd.read_csv(r'D:\Disk C files\OneDrive\Desktop\data for projects\orders.csv', na_values=['Not Available','unknown'])
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# # Rename columns names ..make them lower case and replace space with underscore

# %%
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.rename(columns={'Order Id':'order_id', 'City':'city'})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# # Derive new columns discount , sale price and profit

# %%
df['discount']=df['list_price']*df['discount_percent']*.01
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['sale_price']= df['list_price']-df['discount']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['profit']=df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %% [markdown]
# # Convert order date from object data type to datetime

# %%
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %% [markdown]
# # Drop cost price list price and discount percent columns

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
import mysql.connector

# Step 1: Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",        # Your MySQL host
    user="root",    # Your MySQL username
    password="Shr@2706",# Your MySQL password
    database="orders_db" # Your MySQL database
)
cursor = conn.cursor()

# Step 2: Create a Table (if not already exists)
create_table_query = """
CREATE TABLE IF NOT EXISTS analysis_results (
    id INT AUTO_INCREMENT PRIMARY KEY,
    column1 VARCHAR(255),
    column2 INT,
    column3 FLOAT
    -- Add more columns based on your DataFrame structure
);
"""
cursor.execute(create_table_query)
conn.commit()

print("Table created successfully!")
# Out:
# Table created successfully!

# %% [markdown]
# # Load the data into sql server using append option

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()
import logging

logging.basicConfig()
logging.getLogger('sqlalchemy.engine').setLevel(logging.INFO)

# %%
# Check DataFrame columns
print("DataFrame columns:", df.columns)

# Check database table columns
import sqlalchemy
inspector = sqlalchemy.inspect(conn)
print(inspector.get_columns('df_orders'))
# Out:
# DataFrame columns: Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale_price', 'profit'],
#       dtype='object')
# ---------------------------------------------------------------------------
# NoInspectionAvailable                     Traceback (most recent call last)
# Cell In[12], line 6
#       4 # Check database table columns
#       5 import sqlalchemy
# ----> 6 inspector = sqlalchemy.inspect(conn)
#       7 print(inspector.get_columns('df_orders'))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sqlalchemy\inspection.py:147, in inspect(subject, raiseerr)
#     144     reg = ret = None
#     146 if raiseerr and (reg is None or ret is None):
# --> 147     raise exc.NoInspectionAvailable(
#     148         "No inspection system is "
# ...

# %%
# df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
# Check if the DataFrame column names match the database table
print("DataFrame columns:", df.columns)

# Debugging and setting up correct SQL mapping
df.to_sql(
    name='df_orders',
    con=conn,
    index=False,
    if_exists='append',
    method='multi'  # This can help with inserting multiple rows
)
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:DESCRIBE `orders_db`.`df_orders`
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:
# CREATE TABLE df_orders (
# 	order_id BIGINT,
# 	order_date DATETIME,
# 	ship_mode TEXT,
# 	segment TEXT,
# 	country TEXT,
# 	city TEXT,
# 	state TEXT,
# 	postal_code BIGINT,
# 	region TEXT,
# 	category TEXT,
# 	sub_category TEXT,
# 	product_id TEXT,
# 	quantity BIGINT,
# 	discount FLOAT(53),
# 	sale_price FLOAT(53),
# 	profit FLOAT(53)
# )
#
#
# INFO:sqlalchemy.engine.Engine:[no key 0.00283s] {}
# DataFrame columns: Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale_price', 'profit'],
#       dtype='object')
# ...

# %%
import sqlalchemy as sal
from urllib.parse import quote_plus

# URL encode the password
password = "Shr@2706"
encoded_password = quote_plus(password)

# Use the encoded password in the connection string
engine = sal.create_engine(
    f'mysql+mysqlconnector://root:{encoded_password}@localhost:3306/orders_db'
)

conn = engine.connect()
# Out:
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:[raw sql] {}

# %% [markdown]
# # Load the data into sql server using append option

# %%
df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:DESCRIBE `orders_db`.`df_orders`
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:INSERT INTO df_orders (order_id, order_date, ship_mode, segment, country, city, state, postal_code, region, category, sub_category, product_id, quantity, discount, sale_price, profit) VALUES (%(order_id)s, %(order_date)s, %(ship_mode)s, %(segment)s, %(country)s, %(city)s, %(state)s, %(postal_code)s, %(region)s, %(category)s, %(sub_category)s, %(product_id)s, %(quantity)s, %(discount)s, %(sale_price)s, %(profit)s)
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale_price', 'profit'],
#       dtype='object')
